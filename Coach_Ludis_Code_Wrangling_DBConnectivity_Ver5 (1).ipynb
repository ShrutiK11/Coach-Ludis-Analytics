# %% [markdown]
# # COACH LUDIS CODE (Wrangling, DB Connectivity) - Version 5

# %% [markdown]
# ### DATA WRANGLING

# %% [markdown]
# #### IMPORT STATEMENTS

# %%
# Importing Libraries

# Pandas offers data structures and operations for manipulating numerical tables and time series and for data manipulation and analysis
import pandas as pd

#To read .xlxs files
from pandas import read_excel

# %% [markdown]
# #### INITIALIZATION

# %%
# Loading data using pandas library

# Initializing Sheet name var. All the changes made in the sheet name in the original dataset can be changed here.
# No need to change elsewhere in the code
sheet_name1 = 'BodyPart_InjuryType'
sheet_name2 = 'Mechanism_restALL'
sheet_name3 = 'Injury_AllSports_MF_Count'


# If the .xlsx file name changes, replace 'InjuryData.xlsx' wil 'New_File_Name.xlsx'
file_name = 'InjuryData.xlsx'

# %% [markdown]
# #### READING SHEETS INTO DATAFRAMES

# %%
# Readind data into dataframe

df = read_excel(file_name, sheet_name = sheet_name1)
df

mech_df = read_excel(file_name, sheet_name = sheet_name2)
#mech_df

# %% [markdown]
# ### Code for dealing with "Table S4: Hospitalised football injury cases and population-based rates by age and sex, Australia, 2016–17"

# %%
# Readind data into dataframe

injury_allsport_count_df = read_excel(file_name, sheet_name = sheet_name3)

# Renaming the columns
injury_allsport_count_df.columns = ['Age Group', 'Males_Count', 'Males(per 100,000 population)', '3', 'Females_Count','Females(per 100,000 population)','6','Persons_Count','Persons(per 100,000 population)']
# Dropping all empty columns
injury_allsport_count_df = injury_allsport_count_df.drop(['3', '6'], axis=1) #IMPORTANT COMMAND

injury_allsport_count_df
# Out:
#                                             Age Group Males_Count  \
# 0                                                 NaN       Males
# 1                                                 NaN         NaN
# 2                                    Code of football       Count
# 3                                    Australian rules         NaN
# 4                                                0–14         775
# 5                                               15–24        2085
# 6                                               25–44        1274
# 7                                               45–64          95
# 8                                                 65+           3
# 9                                               Total        4232
# 10                                                NaN         NaN
# 11                                              Rugby         NaN
# 12                                               0–14         996
# 13                                              15–24        1957
# 14                                              25–44        1016
# 15                                              45–64          81
# 16                                                65+           2
# 17                                              Total        4052
# 18                                                NaN         NaN
# 19                                             Soccer         NaN
# 20                                               0–14         974
# 21                                              15–24        1357
# 22                                              25–44        1441
# 23                                              45–64         254
# 24                                                65+           9
# 25                                              Total        4035
# 26                                                NaN         NaN
# 27                                     Touch football         NaN
# 28                                               0–14         102
# 29                                              15–24         194
# 30                                              25–44         235
# 31                                              45–64          36
# 32                                                65+           3
# 33                                              Total         570
# 34                                                NaN         NaN
# 35                       Other & unspecified football         NaN
# 36                                               0–14         529
# 37                                              15–24        1535
# 38                                              25–44         956
# 39                                              45–64          84
# 40                                                65+           8
# 41                                              Total        3112
# 42                                                NaN         NaN
# 43                                       All football         NaN
# 44                                               0–14        3376
# 45                                              15–24        7128
# 46                                              25–44        4922
# 47                                              45–64         550
# 48                                                65+          25
# 49                                              Total       16001
# 50                                             Notes          NaN
# 51  1. This table provides the values charted in F...         NaN
# 52  2. Total (i.e. all ages) rate values were dire...         NaN
# 53                                                NaN         NaN
# 54  Data source: AIHW National Hospital Morbidity ...         NaN
# 55                                                NaN         NaN
# 56                                           Contents         NaN
#
#    Males(per 100,000 population) Females_Count  \
# 0                            NaN       Females
# 1                           Rate           NaN
# 2       (per 100,000 population)         Count
# 3                            NaN           NaN
# 4                        32.7702           110
# 5                        127.946           299
# 6                         37.096           137
# 7                        3.24259             9
# 8                       0.171942             2
# 9                           36.2           557
# 10                           NaN           NaN
# 11                           NaN           NaN
# 12                        42.115           100
# 13                       120.092           240
# 14                       29.5836           121
# 15                       2.76473             4
# 16                      0.114628             0
# 17                          34.6           465
# 18                           NaN           NaN
# 19                           NaN           NaN
# 20                       41.1848           165
# 21                       83.2725           291
# 22                       41.9586           224
# 23                       8.66966            59
# 24                      0.515826             9
# 25                          34.6           748
# 26                           NaN           NaN
# 27                           NaN           NaN
# 28                       4.31298            56
# 29                       11.9048           143
# 30                       6.84267           128
# 31                       1.22877            17
# 32                      0.171942             1
# 33                           4.9           345
# 34                           NaN           NaN
# 35                           NaN           NaN
# 36                       22.3683            70
# 37                       94.1955           157
# 38                       27.8365           128
# 39                       2.86713             9
# 40                      0.458512             1
# 41                          26.6           365
# 42                           NaN           NaN
# 43                           NaN           NaN
# 44                       142.751           501
# 45                       437.411          1130
# 46                       143.317           738
# 47                       18.7729            98
# 48                       1.43285            13
# 49                         136.8          2480
# 50                           NaN           NaN
# 51                           NaN           NaN
# 52                           NaN           NaN
# 53                           NaN           NaN
# 54                           NaN           NaN
# 55                           NaN           NaN
# 56                           NaN           NaN
#
#    Females(per 100,000 population) Persons_Count  \
# 0                              NaN       Persons
# 1                             Rate           NaN
# 2         (per 100,000 population)         Count
# 3                              NaN           NaN
# 4                          4.90874           885
# 5                          19.2175          2384
# 6                          3.95868          1411
# 7                         0.295209           104
# 8                         0.100666             5
# 9                              4.9          4789
# 10                             NaN           NaN
# 11                             NaN           NaN
# 12                         4.46249          1096
# 13                         15.4255          2197
# 14                         3.49636          1137
# 15                        0.131204            85
# 16                               0             2
# 17                             4.1          4517
# 18                             NaN           NaN
# 19                             NaN           NaN
# 20                         7.36311          1139
# 21                         18.7034          1648
# 22                         6.47259          1665
# 23                         1.93526           313
# 24                        0.452996            18
# 25                             6.5          4783
# 26                             NaN           NaN
# 27                             NaN           NaN
# 28                         2.49899           158
# 29                           9.191           337
# 30                         3.69862           363
# 31                        0.557616            53
# 32                       0.0503329             4
# 33                               3           915
# 34                             NaN           NaN
# 35                             NaN           NaN
# 36                         3.12374           599
# 37                         10.0908          1692
# 38                         3.69862          1084
# 39                        0.295209            93
# 40                       0.0503329             9
# 41                             3.2          3477
# 42                             NaN           NaN
# 43                             NaN           NaN
# 44                         22.3571          3877
# 45                         72.6282          8258
# 46                         21.3249          5660
# 47                         3.21449           648
# 48                        0.654327            38
# 49                            21.8         18481
# 50                             NaN           NaN
# 51                             NaN           NaN
# 52                             NaN           NaN
# 53                             NaN           NaN
# 54                             NaN           NaN
# 55                             NaN           NaN
# 56                             NaN           NaN
#
#    Persons(per 100,000 population)
# 0                              NaN
# 1                             Rate
# 2         (per 100,000 population)
# 3                              NaN
# 4                          19.2147
# 5                          74.8401
# 6                          20.4639
# 7                          1.73958
# 8                         0.133993
# 9                             20.8
# 10                             NaN
# 11                             NaN
# 12                         23.7958
# 13                         68.9697
# 14                           16.49
# 15                         1.42177
# 16                        0.053597
# 17                            19.6
# 18                             NaN
# 19                             NaN
# 20                         24.7294
# 21                         51.7351
# 22                         24.1477
# 23                         5.23547
# 24                        0.482373
# 25                            20.7
# 26                             NaN
# 27                             NaN
# 28                         3.43042
# 29                         10.5793
# 30                         5.26462
# 31                        0.886518
# 32                        0.107194
# 33                               4
# 34                             NaN
# 35                             NaN
# 36                         13.0052
# 37                         53.1164
# 38                         15.7214
# 39                         1.55559
# 40                        0.241187
# 41                            15.1
# 42                             NaN
# 43                             NaN
# 44                         84.1755
# 45                         259.241
# 46                         82.0875
# 47                         10.8389
# 48                         1.01834
# 49                            80.1
# 50                             NaN
# 51                             NaN
# 52                             NaN
# 53                             NaN
# 54                             NaN
# 55                             NaN
# 56                             NaN

# %% [markdown]
# #### Creating separate dataframes for each sport type

# %%
#_________FOR AUSTRALIAN RULES__________


injury_Australianrules_count_df = injury_allsport_count_df.iloc[4:10, :]


# To change the column names
injury_Australianrules_count_df = injury_Australianrules_count_df.reset_index(drop=True)

injury_Australianrules_count_df
# Out:
#   Age Group Males_Count Males(per 100,000 population) Females_Count  \
# 0      0–14         775                       32.7702           110
# 1     15–24        2085                       127.946           299
# 2     25–44        1274                        37.096           137
# 3     45–64          95                       3.24259             9
# 4       65+           3                      0.171942             2
# 5     Total        4232                          36.2           557
#
#   Females(per 100,000 population) Persons_Count  \
# 0                         4.90874           885
# 1                         19.2175          2384
# 2                         3.95868          1411
# 3                        0.295209           104
# 4                        0.100666             5
# 5                             4.9          4789
#
#   Persons(per 100,000 population)
# 0                         19.2147
# 1                         74.8401
# 2                         20.4639
# 3                         1.73958
# 4                        0.133993
# 5                            20.8

# %%
#_________FOR RUGBY__________


injury_Rugby_count_df = injury_allsport_count_df.iloc[12:18, :]

injury_Rugby_count_df = injury_Rugby_count_df.reset_index(drop=True)

injury_Rugby_count_df
# Out:
#   Age Group Males_Count Males(per 100,000 population) Females_Count  \
# 0      0–14         996                        42.115           100
# 1     15–24        1957                       120.092           240
# 2     25–44        1016                       29.5836           121
# 3     45–64          81                       2.76473             4
# 4       65+           2                      0.114628             0
# 5     Total        4052                          34.6           465
#
#   Females(per 100,000 population) Persons_Count  \
# 0                         4.46249          1096
# 1                         15.4255          2197
# 2                         3.49636          1137
# 3                        0.131204            85
# 4                               0             2
# 5                             4.1          4517
#
#   Persons(per 100,000 population)
# 0                         23.7958
# 1                         68.9697
# 2                           16.49
# 3                         1.42177
# 4                        0.053597
# 5                            19.6

# %%
#_________FOR SOCCER__________


injury_Soccer_count_df = injury_allsport_count_df.iloc[20:26, :]

injury_Soccer_count_df = injury_Soccer_count_df.reset_index(drop=True)

injury_Soccer_count_df
# Out:
#   Age Group Males_Count Males(per 100,000 population) Females_Count  \
# 0      0–14         974                       41.1848           165
# 1     15–24        1357                       83.2725           291
# 2     25–44        1441                       41.9586           224
# 3     45–64         254                       8.66966            59
# 4       65+           9                      0.515826             9
# 5     Total        4035                          34.6           748
#
#   Females(per 100,000 population) Persons_Count  \
# 0                         7.36311          1139
# 1                         18.7034          1648
# 2                         6.47259          1665
# 3                         1.93526           313
# 4                        0.452996            18
# 5                             6.5          4783
#
#   Persons(per 100,000 population)
# 0                         24.7294
# 1                         51.7351
# 2                         24.1477
# 3                         5.23547
# 4                        0.482373
# 5                            20.7

# %%
#_________FOR TOUCH FOOTBALL__________


injury_TochFootball_count_df = injury_allsport_count_df.iloc[28:34, :]

injury_TochFootball_count_df = injury_TochFootball_count_df.reset_index(drop=True)

injury_TochFootball_count_df
# Out:
#   Age Group Males_Count Males(per 100,000 population) Females_Count  \
# 0      0–14         102                       4.31298            56
# 1     15–24         194                       11.9048           143
# 2     25–44         235                       6.84267           128
# 3     45–64          36                       1.22877            17
# 4       65+           3                      0.171942             1
# 5     Total         570                           4.9           345
#
#   Females(per 100,000 population) Persons_Count  \
# 0                         2.49899           158
# 1                           9.191           337
# 2                         3.69862           363
# 3                        0.557616            53
# 4                       0.0503329             4
# 5                               3           915
#
#   Persons(per 100,000 population)
# 0                         3.43042
# 1                         10.5793
# 2                         5.26462
# 3                        0.886518
# 4                        0.107194
# 5                               4

# %%
#_________FOR OTHER AND UNSPECIFIED FOOTBALL____________________



injury_OtherFootball_count_df = injury_allsport_count_df.iloc[36:42, :]

injury_OtherFootball_count_df = injury_OtherFootball_count_df.reset_index(drop=True)

injury_OtherFootball_count_df
# Out:
#   Age Group Males_Count Males(per 100,000 population) Females_Count  \
# 0      0–14         529                       22.3683            70
# 1     15–24        1535                       94.1955           157
# 2     25–44         956                       27.8365           128
# 3     45–64          84                       2.86713             9
# 4       65+           8                      0.458512             1
# 5     Total        3112                          26.6           365
#
#   Females(per 100,000 population) Persons_Count  \
# 0                         3.12374           599
# 1                         10.0908          1692
# 2                         3.69862          1084
# 3                        0.295209            93
# 4                       0.0503329             9
# 5                             3.2          3477
#
#   Persons(per 100,000 population)
# 0                         13.0052
# 1                         53.1164
# 2                         15.7214
# 3                         1.55559
# 4                        0.241187
# 5                            15.1

# %% [markdown]
# #### Getting Total Injury Count for all the sports - For calculations

# %%
PersonsCount_AustralianRules = injury_Australianrules_count_df.at[0,'Persons_Count']
print ("PersonsCount_AustralianRules :", PersonsCount_AustralianRules)

PersonsCount_Rugby = injury_Rugby_count_df.at[0,'Persons_Count']
print ("PersonsCount_Rugby", PersonsCount_Rugby)

PersonsCount_Soccer = injury_Soccer_count_df.at[0,'Persons_Count']
print ("PersonsCount_Soccer", PersonsCount_Soccer)

PersonsCount_TouchFootball = injury_TochFootball_count_df.at[0,'Persons_Count']
print ("PersonsCount_TouchFootball", PersonsCount_TouchFootball)

PersonsCount_Other = injury_OtherFootball_count_df.at[0,'Persons_Count']
print ("PersonsCount_Other",PersonsCount_Other)

totalHospitalized = PersonsCount_AustralianRules + PersonsCount_Rugby + PersonsCount_Soccer + PersonsCount_TouchFootball + PersonsCount_Other
print ("The total number of hospitalizations for the age group 0-14 is :" ,totalHospitalized)
# Out:
# PersonsCount_AustralianRules : 885
# PersonsCount_Rugby 1096
# PersonsCount_Soccer 1139
# PersonsCount_TouchFootball 158
# PersonsCount_Other 599
# The total number of hospitalizations for the age group 0-14 is : 3877

# %%
#Total Number of hospitalizations was 18,481. Thus the age group 0-14 20.97% (ceiling it to 21%)of the population.

# %% [markdown]
# #### GENERATING DATAFRAME FOR "TYPE OF INJURY" SPECIFICALLY FOR TARGET DEMOGRAPHICS OF 5-10 YEARS OF AGE GROUP

# %%
#____FOR "TYPE OF INJURY"____


# Selecting rows from index 14 to 26
df2 = df.iloc[14:26, :]


# To change the column names
df2 = df2.reset_index(drop=True)
df2.columns = ['Type of Injury', 'Australian rules_Count', 'Australian rules_Percentage', '3', 'Rugby_Count','Rugby_Percentage','6','Soccer_Count','Soccer_Percentage','9', 'Touch football_Count','Touch football_Percentage','12','Other & Unspecified football_Count','Other & Unspecified football_Percentage','15','Total_Count','Total_Percentage']


# Dropping all empty columns
df2 = df2.drop(['3', '6', '9' , '12', '15'], axis=1) #IMPORTANT COMMAND

# For demographic 0-14 years
#df2 = df2['Australian rules_Count','Australian rules_Percentage','Rugby_Count','Rugby_Percentage','Soccer_Count','Soccer_Percentage','Touch football_Count','Touch football_Percentage','Other & Unspecified football_Count','Other & Unspecified football_Percentage','Total_Count','Total_Percentage']*0.21
df2['Australian rules_Count'] = df2['Australian rules_Count']*0.21
#df2['Australian rules_Count'].round(0)
df2['Australian rules_Percentage'] = df2['Australian rules_Percentage']*0.21

df2['Rugby_Count'] = df2['Rugby_Count']*0.21
df2['Rugby_Percentage'] = df2['Rugby_Percentage']*0.21

df2['Soccer_Count'] = df2['Soccer_Count']*0.21
df2['Soccer_Percentage'] = df2['Soccer_Percentage']*0.21

df2['Touch football_Count'] = df2['Touch football_Count']*0.21
df2['Touch football_Percentage'] = df2['Touch football_Percentage']*0.21

df2['Other & Unspecified football_Count'] = df2['Other & Unspecified football_Count']*0.21
df2['Other & Unspecified football_Percentage'] = df2['Other & Unspecified football_Percentage']*0.21

df2['Total_Count'] = df2['Total_Count']*0.21
df2['Total_Percentage'] = df2['Total_Percentage']*0.21



# Print the dataframe
df2
# Out:
#                        Type of Injury Australian rules_Count  \
# 0                            Fracture                 501.27
# 1                         Dislocation                  59.85
# 2                  Soft-tissue injury                 162.33
# 3                          Open wound                  19.74
# 4                 Intracranial injury                 119.28
# 5   Internal organ or vessel of trunk                  30.03
# 6                                Burn                      0
# 7                  Superficial injury                  18.06
# 8           Poisoning or toxic effect                   1.26
# 9                     Other specified                  25.62
# 10                        Unspecified                  68.25
# 11                              Total                1005.69
#
#    Australian rules_Percentage Rugby_Count Rugby_Percentage Soccer_Count  \
# 0                      10.4671      489.72          10.8417       544.74
# 1                      1.24974       51.24          1.13438        32.97
# 2                      3.38964      152.67           3.3799       256.41
# 3                     0.412195       19.11         0.423068        18.27
# 4                      2.49071      102.69          2.27341        53.55
# 5                     0.627062       12.39         0.274297        10.92
# 6                            0           0                0         0.42
# 7                     0.377114       15.33         0.339385        15.33
# 8                    0.0263103        0.63        0.0139473         0.63
# 9                     0.534976       28.98         0.641576        20.37
# 10                     1.42514       75.81          1.67833        50.82
# 11                          21      948.57               21      1004.43
#
#    Soccer_Percentage Touch football_Count Touch football_Percentage  \
# 0            11.3891                94.71                   10.3508
# 1           0.689316                12.81                       1.4
# 2            5.36086                 65.1                   7.11475
# 3           0.381978                 1.89                  0.206557
# 4            1.11959                 5.88                  0.642623
# 5           0.228309                 1.68                  0.183607
# 6          0.0087811                    0                         0
# 7            0.32051                 1.26                  0.137705
# 8          0.0131716                    0                         0
# 9           0.425883                 3.15                  0.344262
# 10           1.06251                 5.67                  0.619672
# 11                21               192.15                        21
#
#    Other & Unspecified football_Count Other & Unspecified football_Percentage  \
# 0                              374.43                                 10.7688
# 1                               38.43                                 1.10526
# 2                              173.88                                 5.00086
# 3                               11.13                                0.320104
# 4                               56.07                                  1.6126
# 5                                9.03                                0.259707
# 6                                   0                                       0
# 7                                9.66                                0.277826
# 8                                   0                                       0
# 9                               16.17                                0.465056
# 10                              41.37                                 1.18982
# 11                             730.17                                      21
#
#    Total_Count Total_Percentage
# 0      2004.87          10.8483
# 1        195.3          1.05676
# 2       810.39          4.38499
# 3        70.14         0.379525
# 4       337.47          1.82604
# 5        64.05         0.346572
# 6         0.42        0.0022726
# 7        59.64          0.32271
# 8         2.52        0.0136356
# 9        94.29           0.5102
# 10      241.92          1.30902
# 11     3881.01               21

# %% [markdown]
# #### GENERATING DATAFRAME FOR "BODY PART INJURED" SPECIFICALLY FOR TARGET DEMOGRAPHICS OF 5-10 YEARS OF AGE GROUP

# %%
#____FOR "BODY PART INJURED"____


# Selecting rows from index 3 to 12
df1 = df.iloc[3:12, :]


# To change the column names
df1 = df1.reset_index(drop=True)
df1.columns = ['Body Part Injured', 'Australian rules_Count', 'Australian rules_Percentage', '3', 'Rugby_Count','Rugby_Percentage','6','Soccer_Count','Soccer_Percentage','9', 'Touch football_Count','Touch football_Percentage','12','Other & Unspecified football_Count','Other & Unspecified football_Percentage','15','Total_Count','Total_Percentage']


# Dropping all empty columns
df1 = df1.drop(['3', '6', '9' , '12', '15'], axis=1) #IMPORTANT COMMAND



# For demographic 0-14 years

df1['Australian rules_Count'] = df1['Australian rules_Count']*0.21
df1['Australian rules_Percentage'] = df1['Australian rules_Percentage']*0.21

df1['Rugby_Count'] = df1['Rugby_Count']*0.21
df1['Rugby_Percentage'] = df1['Rugby_Percentage']*0.21

df1['Soccer_Count'] = df1['Soccer_Count']*0.21
df1['Soccer_Percentage'] = df1['Soccer_Percentage']*0.21

df1['Touch football_Count'] = df1['Touch football_Count']*0.21
df1['Touch football_Percentage'] = df1['Touch football_Percentage']*0.21

df1['Other & Unspecified football_Count'] = df1['Other & Unspecified football_Count']*0.21
df1['Other & Unspecified football_Percentage'] = df1['Other & Unspecified football_Percentage']*0.21

df1['Total_Count'] = df1['Total_Count']*0.21
df1['Total_Percentage'] = df1['Total_Percentage']*0.21


# Print the dataframe
df1
# Out:
#                                    Body Part Injured Australian rules_Count  \
# 0                                      Head and neck                 300.09
# 1  Trunk (thorax, abdomen, lower back, lumb. spin...                  72.87
# 2  Shoulder and upper limb (excluding wrist and h...                 198.66
# 3                                     Wrist and hand                 187.95
# 4      Hip and lower limb (excluding ankle and foot)                 223.44
# 5                                     Ankle and foot                  18.69
# 6  Other, multiple and incompletely specified bod...                   1.26
# 7     Injuries not described in terms of body region                   2.73
# 8                                              Total                1005.69
#
#   Australian rules_Percentage Rugby_Count Rugby_Percentage Soccer_Count  \
# 0                     6.26624      301.77          6.68076       167.79
# 1                     1.52161       53.55          1.18552        38.22
# 2                     4.14826       186.9           4.1377       228.48
# 3                     3.92462       142.8          3.16139        97.65
# 4                     4.66569       241.5          5.34647       440.16
# 5                    0.390269       18.69          0.41377        27.09
# 6                   0.0263103        0.63        0.0139473         1.89
# 7                   0.0570056        2.73        0.0604383         3.15
# 8                          21      948.57               21      1004.43
#
#   Soccer_Percentage Touch football_Count Touch football_Percentage  \
# 0           3.50805                22.47                   2.45574
# 1           0.79908                 5.04                   0.55082
# 2           4.77692                40.11                   4.38361
# 3           2.04161                40.95                   4.47541
# 4           9.20259                77.28                    8.4459
# 5          0.566381                 5.88                  0.642623
# 6         0.0395149                    0                         0
# 7         0.0658582                 0.42                 0.0459016
# 8                21               192.15                        21
#
#   Other & Unspecified football_Count Other & Unspecified football_Percentage  \
# 0                             173.46                                 4.98878
# 1                              28.14                                0.809318
# 2                             139.23                                 4.00431
# 3                              180.6                                 5.19413
# 4                              191.1                                 5.49612
# 5                              14.91                                0.428818
# 6                               1.26                               0.0362381
# 7                               1.47                               0.0422778
# 8                             730.17                                      21
#
#   Total_Count Total_Percentage
# 0      965.58          5.22472
# 1      197.82           1.0704
# 2      793.38          4.29295
# 3      649.95          3.51686
# 4     1173.48          6.34966
# 5       85.26         0.461339
# 6        5.04        0.0272713
# 7        10.5        0.0568151
# 8     3881.01               21

# %% [markdown]
# #### GENERATING DATAFRAME FOR ""MECHANISM OF INJURY" SPECIFICALLY FOR TARGET DEMOGRAPHICS OF 5-10 YEARS OF AGE GROUP

# %%
#____FOR "MECHANISM OF INJURY FOR RUGBY, SOCCER, TOUCH FOOTBALL"____

# Selecting rows from index 2 to 8
mech_df = mech_df.iloc[2:8, :]
 
    
# To change the column names
mech_df = mech_df.reset_index(drop=True)
mech_df.columns = ['Mechanism Of Injury', 'Australian rules_Count', 'Australian rules_Percentage', '3', 'Rugby_Count','Rugby_Percentage','6','Soccer_Count','Soccer_Percentage','9', 'Touch football_Count','Touch football_Percentage','12','Other & Unspecified football_Count','Other & Unspecified football_Percentage','15','Total_Count','Total_Percentage']


# Dropping all empty columns
mech_df = mech_df.drop(['3', '6', '9' , '12', '15'], axis=1) #IMPORTANT COMMAND

# For demographic 0-14 years

mech_df['Australian rules_Count'] = mech_df['Australian rules_Count']*0.21
mech_df['Australian rules_Percentage'] = mech_df['Australian rules_Percentage']*0.21

mech_df['Rugby_Count'] = mech_df['Rugby_Count']*0.21
mech_df['Rugby_Percentage'] = mech_df['Rugby_Percentage']*0.21

mech_df['Soccer_Count'] = mech_df['Soccer_Count']*0.21
mech_df['Soccer_Percentage'] = mech_df['Soccer_Percentage']*0.21

mech_df['Touch football_Count'] = mech_df['Touch football_Count']*0.21
mech_df['Touch football_Percentage'] = mech_df['Touch football_Percentage']*0.21

mech_df['Other & Unspecified football_Count'] = mech_df['Other & Unspecified football_Count']*0.21
mech_df['Other & Unspecified football_Percentage'] = mech_df['Other & Unspecified football_Percentage']*0.21

mech_df['Total_Count'] = mech_df['Total_Count']*0.21
mech_df['Total_Percentage'] = mech_df['Total_Percentage']*0.21

#__________inserting column with static value in data frame 
#__________mech_df.insert(2, "Team", "Asutralian Rules" , "Rugby" , "Soccer" , "Touch_football", "Unspecified_football") 

# Print the dataframe
mech_df
# Out:
#                                  Mechanism Of Injury Australian rules_Count  \
# 0                                              Falls                 307.86
# 1     Striking against or struck by sports equipment                  68.67
# 2                    Interaction with another player                 328.02
# 3  Overexertion and strenuous or repetitive movem...                   67.2
# 4                                   All other causes                 233.94
# 5                                              Total                1005.69
#
#   Australian rules_Percentage Rugby_Count Rugby_Percentage Soccer_Count  \
# 0                     6.42848       445.2           9.8561       352.59
# 1                     1.43391       16.38          0.36263        92.82
# 2                     6.84945      261.45          5.78813        212.1
# 3                     1.40322       63.63          1.40868       113.19
# 4                     4.88494      161.91          3.58446       233.73
# 5                          21      948.57               21      1004.43
#
#   Soccer_Percentage Touch football_Count Touch football_Percentage  \
# 0           7.37173                59.85                   6.54098
# 1           1.94062                 5.25                   0.57377
# 2           4.43446                31.29                   3.41967
# 3           2.36651                40.95                   4.47541
# 4           4.88668                54.81                   5.99016
# 5                21               192.15                        21
#
#   Other & Unspecified football_Count Other & Unspecified football_Percentage  \
# 0                             212.73                                 6.11821
# 1                              39.69                                  1.1415
# 2                             192.57                                  5.5384
# 3                              48.51                                 1.39517
# 4                             236.67                                 6.80673
# 5                             730.17                                      21
#
#   Total_Count Total_Percentage
# 0     1378.23          7.45755
# 1      222.81          1.20562
# 2     1025.43          5.54856
# 3      333.48          1.80445
# 4      921.06          4.98382
# 5     3881.01               21

# %% [markdown]
# ### LEVEL 1 DATASET - COLLISION LEVEL
# ##### Creating Dataframe suitable for Soccer Level1.
# #### MOST FREQUENTLY OCCURING INJURY, PERCENTAGE, SEVERITY

# %%
# Extract specific columns to the new dataframe
level1df = df2[['Type of Injury', 'Soccer_Percentage']].copy()

# Selecting number of rows to be displayed
level1df = level1df.iloc[:11, :]

# Arranging in descending order based on Soccer Percentage
level1df=level1df.sort_values('Soccer_Percentage', ascending=False)

# Selecting top 6 for iteration1 purpose
level1df = level1df.iloc[:7, :]


# Resetting the index
level1df = level1df.reset_index(drop=True)

# Using DataFrame.insert() to add a column 
level1df.insert(2, "Severity", [20, 10, 50, 5, 40 , 5, 30], True) 

level1df.insert(3, "Image_name", ['leg fracture.png', 'soft-tissue injury(leg).png', 'intracranial injury.png', 'unspecified injury.png', 'shoulder dislocation (text).png' , 'other specified injury.png', 'open wound.png'], True) 


level1df
# Out:
#         Type of Injury Soccer_Percentage  Severity  \
# 0             Fracture           11.3891        20
# 1   Soft-tissue injury           5.36086        10
# 2  Intracranial injury           1.11959        50
# 3          Unspecified           1.06251         5
# 4          Dislocation          0.689316        40
# 5      Other specified          0.425883         5
# 6           Open wound          0.381978        30
#
#                         Image_name
# 0                 leg fracture.png
# 1      soft-tissue injury(leg).png
# 2          intracranial injury.png
# 3                       stone2.png
# 4  shoulder dislocation (text).png
# 5       other specified injury.png
# 6                   open wound.png

# %% [markdown]
# ##### FOR UNDERSTANDING THE ASUMPTION OF SEVERITY PLEASE REFER TO THE RECOVERY PERIOD MENTIONED IN THE NEXT CELL

# %%
#____Recovery Period__________
# Fracture 6-8 weeks
# Soft-tissue injury 3-4 weeks 
# Intracranial injury - Type of Brain traum injury - 3-6 months
# Unspecified
# Dislocation 12 - 16 weeks
# Other specified
# Open wound - upto 3 months

# %% [markdown]
# ### CSVs Generated From here -

# %%
# Generating csv ____FOR "BODY PART INJURED"____
# Path can be mentioned df1.to_csv (r'C:\Users\XYZ\ABC\Body Part Injured.csv', index = False, header=True)

df1.to_csv ("Body Part Injured", index = False, header=True)
df1.to_csv (r'C:\Users\Shruti\Desktop\ONE\Monash\2020_Sem_1\FIT5120 IE\MDS PART\Body Part Injured.csv', index = False, header=True)

# %%
#Generating csv ____FOR "TYPE OF INJURY"____

df2.to_csv ("Type of Injury.csv", index = False, header=True)
df2.to_csv (r'C:\Users\Shruti\Desktop\ONE\Monash\2020_Sem_1\FIT5120 IE\MDS PART\Type of Injury.csv', index = False, header=True)

# %%
#Generating csv#____FOR "MECHANISM OF INJURY FOR RUGBY, SOCCER, TOUCH FOOTBALL"____

mech_df.to_csv ("MECHANISM OF INJURY.csv", index = False, header=True)
mech_df.to_csv (r'C:\Users\Shruti\Desktop\ONE\Monash\2020_Sem_1\FIT5120 IE\MDS PART\MECHANISM OF INJURY.csv', index = False, header=True)

# %%
#Generating csv#____FOR "LEVEL1 SOCCER GAME INJURY AND SEVERITY"____

level1df.to_csv ("SOCCER_LEVEL1_INJURY.csv", index = False, header=True)
level1df.to_csv (r'C:\Users\Shruti\Desktop\ONE\Monash\2020_Sem_1\FIT5120 IE\MDS PART\SOCCER_LEVEL1_INJURY.csv', index = False, header=True)

# %% [markdown]
# ### RELATIONAL DB CONNECTION - CANNOT USE RDB AS THE DATASET LACKS STRUCTURE.
# #### PYODBC CONNECTION - Azure connection giving multiple errors.

# %%
#"""Read write to Azure SQL database from pandas"""
#import pyodbc
#import pandas as pd
#import numpy as np
#from sqlalchemy import create_engine

# %%
# 1. Constants
#AZUREUID = 'azureuser'                                    # Azure SQL database userid
#AZUREPWD = 'Coachludis14'                                # Azure SQL database password
#AZURESRV = 'mysqlserver-2.database.windows.net'   # Azure SQL database server name (fully qualified)
#AZUREDB = 'CoachLudisDatabase'                                      # Azure SQL database name (if it does not exit, pandas will create it)
#TABLE = 'DataTable'                                      # Azure SQL database table name
#DRIVER = 'ODBC Driver 13 for SQL Server'                 # ODBC Driver

#def main():
#"""Main function"""
# 2. Build a connectionstring
#connectionstring = 'mssql+pyodbc://{uid}:{password}@{server}:1433/{database}?driver={driver}'.format(
#    uid=AZUREUID,
 #   password=AZUREPWD,
  #  server=AZURESRV,
   # database=AZUREDB,
    #driver=DRIVER.replace(' ', '+'))

# 4. Create SQL Alchemy engine and write data to SQL
#engn = create_engine(connectionstring)
#df1.to_sql(TABLE, engn, if_exists='append')
    
    
#if __name__ == "__main__":
 #   main()

# %%
#cnxn = pyodbc.connect(connectionstring)

# %%
#from sqlalchemy import create_engine
#engine = create_engine('sqlite://', echo=False)

# %%
#server='mysqlserver-2.database.windows.net'
#database='CoachLudisDatabase'
#username='azureuser'
#password='Coachludis14'
#driver='{SQL Server Native Client 11.0}'
#driver='{ODBC Driver 11 for SQL Server}'
#driver='{ODBC Driver 13 for SQL Server}'
#TABLE=""

#cnxn = pyodbc.connect('DRIVER='+driver+';PORT=1433;SERVER='+server+';PORT=1443;DATABASE='+database+';UID='+username+';PWD='+ password)
#cursor = cnxn.cursor()




# 4. Create SQL Alchemy engine and write data to SQL
#df1.to_sql(engn,if_exists='append')

# %%
#engn = create_engine(cnxn)
#df1.to_sql('Body_PartInjured',engn)

# %%
#engine.execute("SELECT * FROM Body_PartInjured").fetchall()

# %% [markdown]
# ## USING NON_RELATIONAL DATABASE AS IT IS SUITABLE FOR THE UNSTRUCTURED DATASET

# %% [markdown]
# ### MongoDB CONNECTION

# %% [markdown]
# #### IMPORT STATEMENTS

# %%
#!pip install pymongo

#from bson.objectid import ObjectId

#from bson.json_util import dumps, loads

from pymongo import MongoClient

#To create rest apis using flask
#from flask import Flask, request, abort, send_file

# Cross origin request
#from flask_cors import CORS

# importing pymongo library
#from flask_pymongo import pymongo

import pymongo

# %% [markdown]
# #### INITIALIZING

# %%
app = Flask(__name__)

cors = CORS(app)

# %% [markdown]
# #### CONNECTION STATEMENTS

# %%
#Connection string after mongo db setup in Mongo atlas for example
CONNECTION_STRING ="mongodb+srv://SSK01:SSK01@ludisanalyticacluster-avpzx.mongodb.net/test?retryWrites=true&w=majority"

# %%
# Creating a pymongo client
client = pymongo.MongoClient(CONNECTION_STRING)

# %%
#Get db
db = client.get_database("CoachLudisDB")

# %% [markdown]
# #### INSERTING RECORDS

# %%
records = db.type_of_injury

# %%
records = db.body_part_injured

# %%
records = db.mechanism_of_injury

# %%
records = db.soccerLevel1

# %%
collection=db["type_of_injury"]

# %%
collection1=db["body_part_injured"]

# %%
collection2=db["mechanism_of_injury"]

# %%
collection3=db["soccerLevel1"]

# %% [markdown]
# #### COUNT DOUCMENTS

# %%
records.count_documents({})
# Out:
# 6

# %% [markdown]
# #### CREATING DIRECTORIES IN THE DB ON THE SERVER
#
# #### Please keep the comments unless required otherwise. Everytime these commands are executed, records get added into the collection

# %%
#collection.insert_many(df2.to_dict("records"))

# %%
#collection1.insert_many(df1.to_dict("records"))

# %%
#collection2.insert_many(mech_df.to_dict("records"))

# %%
#collection3.insert_many(level1df.to_dict("records"))

# %% [markdown]
# #### FETCHING QUERIES. DATA RETRIEVED FROM MONGODB ATLAS

# %%
#___________W O R K S !!! __________________

a = db.type_of_injury.find({'Type of Injury' : 'Fracture'}, {'Soccer_Count' : 1, '_id' : 0})
list(a)
# Out:
# [{'Soccer_Count': 544.74},
#  {'Soccer_Count': 544.74},
#  {'Soccer_Count': 544.74},
#  {'Soccer_Count': 544.74}]

# %%
#a = db.body_part_injured.find({'Type of Injury' : 'Fracture'}, {'Soccer_Count' : 1, '_id' : 0})

# %% [markdown]
# #### SERVER CODE FROM PYMONGO SIDE . . .  IN PROGRESS
#
# #### Server side coding is performed in node.js and works in correspondance to the server. This is a trial attempt from pymongo's end

# %%
#@app.route('/index', methods=['GET'])
#def index():
 #   return("hey")

# %%
#app.run(host='0.0.0.0',port=5000)

# %%
from flask import Flask, request, abort
import json

app = Flask(__name__)



@app.route('/index', methods=['GET'])
def index():
    return("success")


#@app.route(‘/getInjuryCount/<sportName>', methods=['GET'])
 #          def index(sportName):
  #             return("success")




if __name__ == '__main__':
    app.run(debug=True)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-24-dc390742753f> in <module>()
#      19
#      20 if __name__ == '__main__':
# ---> 21     app.run(debug=True)
#      22
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\flask\app.py in run(self, host, port, debug, load_dotenv, **options)
#     936         options.setdefault('threaded', True)
#     937
# --> 938         cli.show_server_banner(self.env, self.debug, self.name, False)
#     939
#     940         from werkzeug.serving import run_simple
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\flask\cli.py in show_server_banner(env, debug, app_import_path, eager_loading)
#     627             message += ' (lazy loading)'
#     628
# --> 629         click.echo(message)
#     630
#     631     click.echo(' * Environment: {0}'.format(env))
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\click\utils.py in echo(message, file, nl, err, color)
#     257
#     258     if message:
# --> 259         file.write(message)
#     260     file.flush()
#     261
#
# UnsupportedOperation: not writable
